# %%
#import lib that are needed.
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data).head()
df
# Out:
#                         _id  _objectID iso_code country_name  \
# 0  5f33f8352e43811b64b96c72          1      AFG  Afghanistan
# 1  5f33f8352e43811b64b96c73          2      AFG  Afghanistan
# 2  5f33f8352e43811b64b96c74          3      AFG  Afghanistan
# 3  5f33f8352e43811b64b96c75          4      AFG  Afghanistan
# 4  5f33f8352e43811b64b96c76          5      AFG  Afghanistan
#
#                 Date_epicrv NewCase TotalCase NewDeath TotalDeath
# 0  2020-02-24T00:00:00.000Z       1         1        0          0
# 1  2020-02-25T00:00:00.000Z       0         1        0          0
# 2  2020-02-26T00:00:00.000Z       0         1        0          0
# 3  2020-02-27T00:00:00.000Z       0         1        0          0
# 4  2020-02-28T00:00:00.000Z       0         1        0          0

# %%
#import lib
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data).head(200)

#plot a basic graph to test
#using matplotlib
plt.plot(df.iso_code,df.country_name)
plt.show()

# %%
#plotting a seaborn graph 

#needed lib
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data,dtype=float).head(150)

#creating simple line plot
ax = sns.lineplot(x='iso_code',y='NewCase',data = df)

# %%
#plotting a seaborn graph 

#needed lib
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data,dtype=float).head(150)

#creating simple bar plot
sns.set(style="whitegrid")
ax = sns.barplot(x='iso_code',y='NewCase',data = df)

# %%
#plotting a seaborn graph 

#needed lib
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data,dtype=float).head(100)

#plotting one coloumn from data using seaborn 
x = df['NewCase'].values
sns.boxplot(x)

# %%
#plotting a seaborn graph 

#needed lib
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data,dtype=float).head(150)

#creating simple bar plot
ax = sns.relplot(x='iso_code',y='NewCase',data = df)

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show
from bokeh.plotting import figure

# %%
#plotting a seaborn graph 

#needed lib
from bokeh.io import show
from bokeh.plotting import figure
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#connect to mongodb
cluster = MongoClient('mongodb+srv://Nadine:0711783663Nt@reportingdata.bup2b.mongodb.net/sprint3retryWrites=true&w=majority')
db= cluster['sprint3']
collection = db['data']

#create dataframe
data = collection.find({})
df = pd.DataFrame.from_dict(data).head(200)


first_graph = figure(height=300)
first_graph.circle(x=df.NewCase,y=df.TotalCase,color='purple')
show(first_graph)
# Out:
#   <div class="bk-root" id="6993868d-9960-4e6b-90fa-01907de3eeb7" data-root-id="2815"></div>
